# %% [markdown]
# <a href="https://colab.research.google.com/github/padhisagar/Data_Science_Learning/blob/main/TimeSeries_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
df = pd.read_csv('Electric_Production.csv',index_col=0)

# %%
df.head(5)
# Out:
#           IPG2211A2N
# DATE
# 1/1/1985     72.5052
# 2/1/1985     70.6720
# 3/1/1985     62.4502
# 4/1/1985     57.4714
# 5/1/1985     55.3151

# %%
df.tail()
# Out:
#            IPG2211A2N
# DATE
# 9/1/2017      98.6154
# 10/1/2017     93.6137
# 11/1/2017     97.3359
# 12/1/2017    114.7212
# 1/1/2018     129.4048

# %%
df.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='DATE'>

# %%
df.loc['9/1/2017':'1/1/2018'].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
df
# Out:
#            IPG2211A2N
# DATE
# 1/1/1985      72.5052
# 2/1/1985      70.6720
# 3/1/1985      62.4502
# 4/1/1985      57.4714
# 5/1/1985      55.3151
# ...               ...
# 9/1/2017      98.6154
# 10/1/2017     93.6137
# 11/1/2017     97.3359
# 12/1/2017    114.7212
# 1/1/2018     129.4048
#
# [397 rows x 1 columns]

# %%
df.shape
# Out:
# (397, 1)

# %%
df.describe()
# Out:
#        IPG2211A2N
# count  397.000000
# mean    88.847218
# std     15.387834
# min     55.315100
# 25%     77.105200
# 50%     89.779500
# 75%    100.524400
# max    129.404800

# %%
df
# Out:
#            IPG2211A2N
# DATE
# 1/1/1985      72.5052
# 2/1/1985      70.6720
# 3/1/1985      62.4502
# 4/1/1985      57.4714
# 5/1/1985      55.3151
# ...               ...
# 9/1/2017      98.6154
# 10/1/2017     93.6137
# 11/1/2017     97.3359
# 12/1/2017    114.7212
# 1/1/2018     129.4048
#
# [397 rows x 1 columns]

# %%
df = df.reset_index()

# %%
df
# Out:
#           DATE  IPG2211A2N
# 0     1/1/1985     72.5052
# 1     2/1/1985     70.6720
# 2     3/1/1985     62.4502
# 3     4/1/1985     57.4714
# 4     5/1/1985     55.3151
# ..         ...         ...
# 392   9/1/2017     98.6154
# 393  10/1/2017     93.6137
# 394  11/1/2017     97.3359
# 395  12/1/2017    114.7212
# 396   1/1/2018    129.4048
#
# [397 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATE        397 non-null    object
#  1   IPG2211A2N  397 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 6.3+ KB

# %%
df
# Out:
#           DATE  IPG2211A2N
# 0     1/1/1985     72.5052
# 1     2/1/1985     70.6720
# 2     3/1/1985     62.4502
# 3     4/1/1985     57.4714
# 4     5/1/1985     55.3151
# ..         ...         ...
# 392   9/1/2017     98.6154
# 393  10/1/2017     93.6137
# 394  11/1/2017     97.3359
# 395  12/1/2017    114.7212
# 396   1/1/2018    129.4048
#
# [397 rows x 2 columns]

# %%
df['DATE'] = pd.to_datetime(df['DATE'])

# %%
df
# Out:
#           DATE  IPG2211A2N
# 0   1985-01-01     72.5052
# 1   1985-02-01     70.6720
# 2   1985-03-01     62.4502
# 3   1985-04-01     57.4714
# 4   1985-05-01     55.3151
# ..         ...         ...
# 392 2017-09-01     98.6154
# 393 2017-10-01     93.6137
# 394 2017-11-01     97.3359
# 395 2017-12-01    114.7212
# 396 2018-01-01    129.4048
#
# [397 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATE        397 non-null    datetime64[ns]
#  1   IPG2211A2N  397 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 6.3 KB

# %%
df = df.set_index('DATE',drop=True)

# %%
df
# Out:
#             IPG2211A2N
# DATE
# 1985-01-01     72.5052
# 1985-02-01     70.6720
# 1985-03-01     62.4502
# 1985-04-01     57.4714
# 1985-05-01     55.3151
# ...                ...
# 2017-09-01     98.6154
# 2017-10-01     93.6137
# 2017-11-01     97.3359
# 2017-12-01    114.7212
# 2018-01-01    129.4048
#
# [397 rows x 1 columns]

# %%
df.resample(rule='A').min()
# Out:
#             IPG2211A2N
# DATE
# 1985-12-31     55.3151
# 1986-12-31     55.8137
# 1987-12-31     58.8734
# 1988-12-31     61.4065
# 1989-12-31     63.6892
# 1990-12-31     65.8218
# 1991-12-31     67.1500
# 1992-12-31     67.1784
# 1993-12-31     67.6762
# 1994-12-31     69.3844
# 1995-12-31     73.2682
# 1996-12-31     74.6891
# 1997-12-31     73.8471
# 1998-12-31     76.7521
# 1999-12-31     79.3887
# 2000-12-31     81.4425
# 2001-12-31     82.5465
# 2002-12-31     85.2351
# 2003-12-31     85.0620
# 2004-12-31     86.7233
# 2005-12-31     86.4776
# 2006-12-31     87.5093
# 2007-12-31     90.8177
# 2008-12-31     90.9944
# 2009-12-31     87.5366
# 2010-12-31     86.3000
# 2011-12-31     89.3583
# 2012-12-31     87.5566
# 2013-12-31     90.9634
# 2014-12-31     90.2867
# 2015-12-31     89.7461
# 2016-12-31     89.3254
# 2017-12-31     88.3530
# 2018-12-31    129.4048

# %%
df.resample(rule='A').max().head()
# Out:
#             IPG2211A2N
# DATE
# 1985-12-31     72.5052
# 1986-12-31     73.3057
# 1987-12-31     73.8152
# 1988-12-31     79.8703
# 1989-12-31     84.1949

# %%
df.resample(rule='A').max().plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
df['IPG2211A2N'].rolling(3).max().head(3)
# Out:
# DATE
# 1985-01-01        NaN
# 1985-02-01        NaN
# 1985-03-01    72.5052
# Name: IPG2211A2N, dtype: float64

# %% [markdown]
# # New section
