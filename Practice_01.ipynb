# %% [markdown]
# <a href="https://colab.research.google.com/github/padhisagar/Data_Science_Learning/blob/main/Practice_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('waterDataMaster.csv')

# %%
df.head()
# Out:
#     BOD                       _id className  dissolvedOxygen  fecalColiform  \
# 0  16.0  621f2eaa9ddbed367f4d8ec8         B              2.2           25.0
# 1   3.0  621f2eaa9ddbed367f4d8ec9         B              5.9           11.0
# 2   4.4  621f2eaa9ddbed367f4d8eca         B              3.8           13.0
# 3   3.8  621f2eaa9ddbed367f4d8ecb         B              6.5      -999999.0
# 4   3.2  621f2eaa9ddbed367f4d8ecc         B              5.0           14.0
#
#    nitrate    pH                  readDate  stnId    wqi
# 0      0.7  7.54  2021-03-10T00:00:00.000Z   2178  47.65
# 1      2.4  7.00  2021-03-10T00:00:00.000Z   2183  82.76
# 2      0.8  7.64  2021-03-10T00:00:00.000Z   2181  68.00
# 3      0.4  8.09  2021-03-10T00:00:00.000Z   2161  61.33
# 4      0.3  7.84  2021-03-10T00:00:00.000Z   2664  74.74

# %%
df.drop(['_id','className'],inplace=True,axis=1)

# %%
df.head()
# Out:
#     BOD  dissolvedOxygen  fecalColiform  nitrate    pH  \
# 0  16.0              2.2           25.0      0.7  7.54
# 1   3.0              5.9           11.0      2.4  7.00
# 2   4.4              3.8           13.0      0.8  7.64
# 3   3.8              6.5      -999999.0      0.4  8.09
# 4   3.2              5.0           14.0      0.3  7.84
#
#                    readDate  stnId    wqi
# 0  2021-03-10T00:00:00.000Z   2178  47.65
# 1  2021-03-10T00:00:00.000Z   2183  82.76
# 2  2021-03-10T00:00:00.000Z   2181  68.00
# 3  2021-03-10T00:00:00.000Z   2161  61.33
# 4  2021-03-10T00:00:00.000Z   2664  74.74

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26654 entries, 0 to 26653
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BOD              26654 non-null  float64
#  1   dissolvedOxygen  26654 non-null  float64
#  2   fecalColiform    26654 non-null  float64
#  3   nitrate          26654 non-null  float64
#  4   pH               26654 non-null  float64
#  5   readDate         26654 non-null  object
#  6   stnId            26654 non-null  int64
#  7   wqi              26654 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 1.6+ MB

# %%
df['readDate'] = pd.to_datetime(df['readDate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26654 entries, 0 to 26653
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BOD              26654 non-null  float64
#  1   dissolvedOxygen  26654 non-null  float64
#  2   fecalColiform    26654 non-null  float64
#  3   nitrate          26654 non-null  float64
#  4   pH               26654 non-null  float64
#  5   readDate         26654 non-null  datetime64[ns, UTC]
#  6   stnId            26654 non-null  int64
#  7   wqi              26654 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(6), int64(1)
# memory usage: 1.6 MB

# %%
df = df.set_index('readDate',drop=True)

# %%
df['pH'].plot()
# Out:
# <Axes: xlabel='readDate'>

# %%
df.head()
# Out:
#                             BOD  dissolvedOxygen  fecalColiform  nitrate  \
# readDate
# 2021-03-10 00:00:00+00:00  16.0              2.2           25.0      0.7
# 2021-03-10 00:00:00+00:00   3.0              5.9           11.0      2.4
# 2021-03-10 00:00:00+00:00   4.4              3.8           13.0      0.8
# 2021-03-10 00:00:00+00:00   3.8              6.5      -999999.0      0.4
# 2021-03-10 00:00:00+00:00   3.2              5.0           14.0      0.3
#
#                              pH  stnId    wqi
# readDate
# 2021-03-10 00:00:00+00:00  7.54   2178  47.65
# 2021-03-10 00:00:00+00:00  7.00   2183  82.76
# 2021-03-10 00:00:00+00:00  7.64   2181  68.00
# 2021-03-10 00:00:00+00:00  8.09   2161  61.33
# 2021-03-10 00:00:00+00:00  7.84   2664  74.74
